# %%
# !pip install intrinio-sdk
# Out:
# Collecting intrinio-sdk
#   Downloading https://files.pythonhosted.org/packages/32/de/7bfda8a5846444acd28a287c49794c391f8e24bdcb62f984e3b98c0e4563/intrinio_sdk-4.0.0-py3-none-any.whl (796kB)
#      |████████████████████████████████| 798kB 2.3MB/s eta 0:00:01
# Requirement already satisfied: six>=1.10 in /Users/azel/anaconda3/lib/python3.7/site-packages (from intrinio-sdk) (1.12.0)
# Requirement already satisfied: python-dateutil in /Users/azel/anaconda3/lib/python3.7/site-packages (from intrinio-sdk) (2.8.0)
# Requirement already satisfied: urllib3>=1.15 in /Users/azel/anaconda3/lib/python3.7/site-packages (from intrinio-sdk) (1.24.2)
# Requirement already satisfied: certifi in /Users/azel/anaconda3/lib/python3.7/site-packages (from intrinio-sdk) (2019.6.16)
# Installing collected packages: intrinio-sdk
# Successfully installed intrinio-sdk-4.0.0

# %%
from __future__ import print_function
import time
import intrinio_sdk
from intrinio_sdk.rest import ApiException
from pprint import pprint

# %%
intrinio_sdk.ApiClient().configuration.api_key['api_key'] = 'api key here'

security_api = intrinio_sdk.SecurityApi()

# %%
identifier = 'AAPL' # str | A Security identifier (Ticker, FIGI, ISIN, CUSIP, Intrinio ID)
start_date = '2018-01-01' # date | Return prices on or after the date (optional)
end_date = '2019-01-01' # date | Return prices on or before the date (optional)
frequency = 'daily' # str | Return stock prices in the given frequency (optional) (default to daily)
page_size = 100 # int | The number of results to return (optional) (default to 100)
next_page = '' # str | Gets the next page of data from a previous API call (optional)

# %%
try:
    api_response = security_api.get_security_stock_prices(identifier, 
                                                        start_date=start_date, 
                                                        end_date=end_date, 
                                                        frequency=frequency, 
                                                        page_size=page_size, 
                                                        next_page=next_page)
    pprint(api_response)
    
except ApiException as e:
    print("Exception when calling SecurityApi->get_security_stock_prices: %s\r\n" % e)
# Out:
# {'next_page': 'MjAxOC0wOC0wOHwxMDE5MDU0NzE5MA==',
#  'security': {'code': 'EQS',
#               'company_id': 'com_NX6GzO',
#               'composite_figi': 'BBG000B9XRY4',
#               'composite_ticker': 'AAPL:US',
#               'currency': 'USD',
#               'figi': 'BBG000B9Y5X2',
#               'id': 'sec_agjrgj',
#               'name': 'Apple Inc',
#               'share_class_figi': 'BBG001S5N8V8',
#               'ticker': 'AAPL'},
#  'stock_prices': [{'adj_close': 156.463834260369,
#                    'adj_high': 158.070727955702,
#                    'adj_low': 155.214028052888,
#                    'adj_open': 157.247442914266,
#                    'adj_volume': 35003466.0,
#                    'close': 157.74,
#                    'date': datetime.date(2018, 12, 31),
#                    'frequency': 'daily',
#                    'high': 159.36,
#                    'intraperiod': False,
#                    'low': 156.48,
#                    'open': 158.53,
#                    'volume': 35003466.0},
#                   {'adj_close': 154.966050630769,
#                    'adj_high': 157.237523817381,
#                    'adj_low': 153.299642354127,
#                    'adj_open': 156.225775935135,
#                    'adj_volume': 42291424.0,
#                    'close': 156.23,
#                    'date': datetime.date(2018, 12, 28),
#                    'frequency': 'daily',
#                    'high': 158.52,
#                    'intraperiod': False,
#                    'low': 154.55,
#                    'open': 157.5,
#                    'volume': 42291424.0},
#                   {'adj_close': 154.886697855691,
#                    'adj_high': 155.501681862547,
#                    'adj_low': 148.85588694975,
#                    'adj_open': 154.579205852263,
#                    'adj_volume': 53117065.0,
#                    'close': 156.15,
#                    'date': datetime.date(2018, 12, 27),
#                    'frequency': 'daily',
#                    'high': 156.77,
#                    'intraperiod': False,
#                    'low': 150.07,
#                    'open': 155.84,
#                    'volume': 53117065.0},
#                   {'adj_close': 155.898445737937,
#                    'adj_high': 155.957960319246,
#                    'adj_low': 145.532989493352,
#                    'adj_open': 147.100206801146,
#                    'adj_volume': 58582544.0,
#                    'close': 157.17,
#                    'date': datetime.date(2018, 12, 26),
#                    'frequency': 'daily',
#                    'high': 157.23,
#                    'intraperiod': False,
#                    'low': 146.72,
#                    'open': 148.3,
#                    'volume': 58582544.0},
#                   {'adj_close': 145.642099559085,
#                    'adj_high': 150.323913288696,
#                    'adj_low': 145.40404123385,
#                    'adj_open': 146.951420347874,
#                    'adj_volume': 37169232.0,
#                    'close': 146.83,
#                    'date': datetime.date(2018, 12, 24),
#                    'frequency': 'daily',
#                    'high': 151.55,
#                    'intraperiod': False,
#                    'low': 146.59,
#                    'open': 148.15,
#                    'volume': 37169232.0},
#                   {'adj_close': 149.510547344145,
#                    'adj_high': 156.88043632953,
#                    'adj_low': 148.41944668682,
#                    'adj_open': 155.590953734509,
#                    'adj_volume': 95744384.0,
#                    'close': 150.73,
#                    'date': datetime.date(2018, 12, 21),
#                    'frequency': 'daily',
#                    'high': 158.16,
#                    'intraperiod': False,
#                    'low': 149.63,
#                    'open': 156.86,
#                    'volume': 95744384.0},
#                   {'adj_close': 155.561196443855,
#                    'adj_high': 160.798479599014,
#                    'adj_low': 154.043574620485,
#                    'adj_open': 159.102314031718,
#                    'adj_volume': 64772960.0,
#                    'close': 156.83,
#                    'date': datetime.date(2018, 12, 20),
#                    'frequency': 'daily',
#                    'high': 162.11,
#                    'intraperiod': False,
#                    'low': 155.3,
#                    'open': 160.4,
#                    'volume': 64772960.0},
#                   {'adj_close': 159.588349779072,
#                    'adj_high': 166.095277335481,
#                    'adj_low': 157.802912339813,
#                    'adj_open': 164.65700828719,
#                    'adj_volume': 49047297.0,
#                    'close': 160.89,
#                    'date': datetime.date(2018, 12, 19),
#                    'frequency': 'daily',
#                    'high': 167.45,
#                    'intraperiod': False,
#                    'low': 159.09,
#                    'open': 166.0,
#                    'volume': 49047297.0},
#                   {'adj_close': 164.726441965383,
#                    'adj_high': 166.17463011056,
#                    'adj_low': 163.060033688742,
#                    'adj_open': 164.042024280334,
#                    'adj_volume': 33841518.0,
#                    'close': 166.07,
#                    'date': datetime.date(2018, 12, 18),
#                    'frequency': 'daily',
#                    'high': 167.53,
#                    'intraperiod': False,
#                    'low': 164.39,
#                    'open': 165.38,
#                    'volume': 33841518.0},
#                   {'adj_close': 162.613674328927,
#                    'adj_high': 166.987996055111,
#                    'adj_low': 161.41346360587,
#                    'adj_open': 164.111457958527,
#                    'adj_volume': 44287922.0,
#                    'close': 163.94,
#                    'date': datetime.date(2018, 12, 17),
#                    'frequency': 'daily',
#                    'high': 168.35,
#                    'intraperiod': False,
#                    'low': 162.73,
#                    'open': 165.45,
#                    'volume': 44287922.0},
#                   {'adj_close': 164.141215249182,
#                    'adj_high': 167.712090127699,
#                    'adj_low': 163.942833311486,
#                    'adj_open': 167.632737352621,
#                    'adj_volume': 40703710.0,
#                    'close': 165.48,
#                    'date': datetime.date(2018, 12, 14),
#                    'frequency': 'daily',
#                    'high': 169.08,
#                    'intraperiod': False,
#                    'low': 165.28,
#                    'open': 169.0,
#                    'volume': 40703710.0},
#                   {'adj_close': 169.566961245151,
#                    'adj_high': 171.173854940484,
#                    'adj_low': 168.178287681283,
#                    'adj_open': 169.110682788452,
#                    'adj_volume': 31897827.0,
#                    'close': 170.95,
#                    'date': datetime.date(2018, 12, 13),
#                    'frequency': 'daily',
#                    'high': 172.57,
#                    'intraperiod': False,
#                    'low': 169.55,
#                    'open': 170.49,
#                    'volume': 31897827.0},
#                   {'adj_close': 167.731928321468,
#                    'adj_high': 170.529113642974,
#                    'adj_low': 167.65257554639,
#                    'adj_open': 169.021410916489,
#                    'adj_volume': 35627674.0,
#                    'close': 169.1,
#                    'date': datetime.date(2018, 12, 12),
#                    'frequency': 'daily',
#                    'high': 171.92,
#                    'intraperiod': False,
#                    'low': 169.02,
#                    'open': 170.4,
#                    'volume': 35627674.0},
#                   {'adj_close': 167.265730767884,
#                    'adj_high': 170.400165383472,
#                    'adj_low': 165.648917975667,
#                    'adj_open': 170.27121712397,
#                    'adj_volume': 47281665.0,
#                    'close': 168.63,
#                    'date': datetime.date(2018, 12, 11),
#                    'frequency': 'daily',
#                    'high': 171.79,
#                    'intraperiod': False,
#                    'low': 167.0,
#                    'open': 171.66,
#                    'volume': 47281665.0},
#                   {'adj_close': 168.227883165707,
#                    'adj_high': 168.713918913061,
#                    'adj_low': 162.008609418956,
#                    'adj_open': 163.665098598713,
#                    'adj_volume': 62025994.0,
#                    'close': 169.6,
#                    'date': datetime.date(2018, 12, 10),
#                    'frequency': 'daily',
#                    'high': 170.09,
#                    'intraperiod': False,
#                    'low': 163.33,
#                    'open': 165.0,
#                    'volume': 62025994.0},
#                   {'adj_close': 167.126863411497,
#                    'adj_high': 173.07832154236,
#                    'adj_low': 166.938400570687,
#                    'adj_open': 172.086411853883,
#                    'adj_volume': 42281631.0,
#                    'close': 168.49,
#                    'date': datetime.date(2018, 12, 7),
#                    'frequency': 'daily',
#                    'high': 174.49,
#                    'intraperiod': False,
#                    'low': 168.3,
#                    'open': 173.49,
#                    'volume': 42281631.0},
#                   {'adj_close': 173.306460770709,
#                    'adj_high': 173.365975352018,
#                    'adj_low': 169.041249110258,
#                    'adj_open': 170.370408092817,
#                    'adj_volume': 43098410.0,
#                    'close': 174.72,
#                    'date': datetime.date(2018, 12, 6),
#                    'frequency': 'daily',
#                    'high': 174.78,
#                    'intraperiod': False,
#                    'low': 170.42,
#                    'open': 171.76,
#                    'volume': 43098410.0},
#                   {'adj_close': 175.260522857009,
#                    'adj_high': 180.91430889036,
#                    'adj_low': 174.843920787849,
#                    'adj_open': 179.486058129921,
#                    'adj_volume': 41344282.0,
#                    'close': 176.69,
#                    'date': datetime.date(2018, 12, 4),
#                    'frequency': 'daily',
#                    'high': 182.3899,
#                    'intraperiod': False,
#                    'low': 176.27,
#                    'open': 180.95,
#                    'volume': 41344282.0},
#                   {'adj_close': 183.324748624328,
#                    'adj_high': 183.443777786945,
#                    'adj_low': 179.743954648925,
#                    'adj_open': 182.967661136476,
#                    'adj_volume': 40798002.0,
#                    'close': 184.82,
#                    'date': datetime.date(2018, 12, 3),
#                    'frequency': 'daily',
#                    'high': 184.94,
#                    'intraperiod': False,
#                    'low': 181.21,
#                    'open': 184.46,
#                    'volume': 40798002.0},
#                   {'adj_close': 177.135232168231,
#                    'adj_high': 178.871074123066,
#                    'adj_low': 175.597772151091,
#                    'adj_open': 178.831397735527,
#                    'adj_volume': 39531549.0,
#                    'close': 178.58,
#                    'date': datetime.date(2018, 11, 30),
#                    'frequency': 'daily',
#                    'high': 180.33,
#                    'intraperiod': False,
#                    'low': 177.03,
#                    'open': 180.29,
#                    'volume': 39531549.0},
#                   {'adj_close': 178.097384566054,
#                    'adj_high': 181.321091053604,
#                    'adj_low': 176.262351642371,
#                    'adj_open': 181.182223697217,
#                    'adj_volume': 41769992.0,
#                    'close': 179.55,
#                    'date': datetime.date(2018, 11, 29),
#                    'frequency': 'daily',
#                    'high': 182.8,
#                    'intraperiod': False,
#                    'low': 177.7,
#                    'open': 182.66,
#                    'volume': 41769992.0},
#                   {'adj_close': 179.476139033037,
#                    'adj_high': 179.823307424004,
#                    'adj_low': 173.51476180529,
#                    'adj_open': 175.300199244548,
#                    'adj_volume': 46062539.0,
#                    'close': 180.94,
#                    'date': datetime.date(2018, 11, 28),
#                    'frequency': 'daily',
#                    'high': 181.29,
#                    'intraperiod': False,
#                    'low': 174.93,
#                    'open': 176.73,
#                    'volume': 46062539.0},
#                   {'adj_close': 172.830344120241,
#                    'adj_high': 173.356056255133,
#                    'adj_low': 169.497527566958,
#                    'adj_open': 170.122430670698,
#                    'adj_volume': 41387377.0,
#                    'close': 174.24,
#                    'date': datetime.date(2018, 11, 27),
#                    'frequency': 'daily',
#                    'high': 174.77,
#                    'intraperiod': False,
#                    'low': 170.88,
#                    'open': 171.51,
#                    'volume': 41387377.0},
#                   {'adj_close': 173.207269801862,
#                    'adj_high': 173.534599999059,
#                    'adj_low': 168.882543560102,
#                    'adj_open': 172.830344120241,
#                    'adj_volume': 44998520.0,
#                    'close': 174.62,
#                    'date': datetime.date(2018, 11, 26),
#                    'frequency': 'daily',
#                    'high': 174.95,
#                    'intraperiod': False,
#                    'low': 170.26,
#                    'open': 174.24,
#                    'volume': 44998520.0},
#                   {'adj_close': 170.89612022771,
#                    'adj_high': 175.166291436604,
#                    'adj_low': 170.7076573869,
#                    'adj_open': 173.524680902174,
#                    'adj_volume': 23623972.0,
#                    'close': 172.29,
#                    'date': datetime.date(2018, 11, 23),
#                    'frequency': 'daily',
#                    'high': 176.595,
#                    'intraperiod': False,
#                    'low': 172.1,
#                    'open': 174.94,
#                    'volume': 23623972.0},
#                   {'adj_close': 175.349794728972,
#                    'adj_high': 178.811559541757,
#                    'adj_low': 175.121655500622,
#                    'adj_open': 178.275928309979,
#                    'adj_volume': 31124210.0,
#                    'close': 176.78,
#                    'date': datetime.date(2018, 11, 21),
#                    'frequency': 'daily',
#                    'high': 180.27,
#                    'intraperiod': False,
#                    'low': 176.55,
#                    'open': 179.73,
#                    'volume': 31124210.0},
#                   {'adj_close': 175.548176666668,
#                    'adj_high': 180.00185116793,
#                    'adj_low': 174.090069424606,
#                    'adj_open': 176.926931133651,
#                    'adj_volume': 67825247.0,
#                    'close': 176.98,
#                    'date': datetime.date(2018, 11, 20),
#                    'frequency': 'daily',
#                    'high': 181.47,
#                    'intraperiod': False,
#                    'low': 175.51,
#                    'open': 178.37,
#                    'volume': 67825247.0},
#                   {'adj_close': 184.356334700344,
#                    'adj_high': 189.157177592573,
#                    'adj_low': 183.493373271369,
#                    'adj_open': 188.462840810639,
#                    'adj_volume': 41920872.0,
#                    'close': 185.86,
#                    'date': datetime.date(2018, 11, 19),
#                    'frequency': 'daily',
#                    'high': 190.7,
#                    'intraperiod': False,
#                    'low': 184.99,
#                    'open': 190.0,
#                    'volume': 41920872.0},
#                   {'adj_close': 191.964282010963,
#                    'adj_high': 193.392136007525,
#                    'adj_low': 187.927209578861,
#                    'adj_open': 188.958795654877,
#                    'adj_volume': 36928253.0,
#                    'close': 193.53,
#                    'date': datetime.date(2018, 11, 16),
#                    'frequency': 'daily',
#                    'high': 194.9695,
#                    'intraperiod': False,
#                    'low': 189.46,
#                    'open': 190.5,
#                    'volume': 36928253.0},
#                   {'adj_close': 189.861433471391,
#                    'adj_high': 190.416902896939,
#                    'adj_low': 185.38792077636,
#                    'adj_open': 186.865866212191,
#                    'adj_volume': 46478801.0,
#                    'close': 191.41,
#                    'date': datetime.date(2018, 11, 15),
#                    'frequency': 'daily',
#                    'high': 191.97,
#                    'intraperiod': False,
#                    'low': 186.9,
#                    'open': 188.39,
#                    'volume': 46478801.0},
#                   {'adj_close': 185.288729807512,
#                    'adj_high': 192.906596215016,
#                    'adj_low': 184.425768378537,
#                    'adj_open': 192.331288595699,
#                    'adj_volume': 60800957.0,
#                    'close': 186.8,
#                    'date': datetime.date(2018, 11, 14),
#                    'frequency': 'daily',
#                    'high': 194.48,
#                    'intraperiod': False,
#                    'low': 185.93,
#                    'open': 193.9,
#                    'volume': 60800957.0},
#                   {'adj_close': 190.674799415943,
#                    'adj_high': 195.584752373904,
#                    'adj_low': 189.901209049899,
#                    'adj_open': 190.079653602856,
#                    'adj_volume': 46882936.0,
#                    'close': 192.23,
#                    'date': datetime.date(2018, 11, 13),
#                    'frequency': 'daily',
#                    'high': 197.18,
#                    'intraperiod': False,
#                    'low': 191.4501,
#                    'open': 191.63,
#                    'volume': 46882936.0},
#                   {'adj_close': 192.599104211588,
#                    'adj_high': 198.233151242138,
#                    'adj_low': 192.222178529967,
#                    'adj_open': 197.390028006932,
#                    'adj_volume': 51135518.0,
#                    'close': 194.17,
#                    'date': datetime.date(2018, 11, 12),
#                    'frequency': 'daily',
#                    'high': 199.85,
#                    'intraperiod': False,
#                    'low': 193.79,
#                    'open': 199.0,
#                    'volume': 51135518.0},
#                   {'adj_close': 202.815774002902,
#                    'adj_high': 204.343314923156,
#                    'adj_low': 200.613734494483,
#                    'adj_open': 203.887036466457,
#                    'adj_volume': 34365750.0,
#                    'close': 204.47,
#                    'date': datetime.date(2018, 11, 9),
#                    'frequency': 'daily',
#                    'high': 206.01,
#                    'intraperiod': False,
#                    'low': 202.25,
#                    'open': 205.55,
#                    'volume': 34365750.0},
#                   {'adj_close': 206.803250950579,
#                    'adj_high': 208.420063742797,
#                    'adj_low': 205.077328092629,
#                    'adj_open': 208.28119638641,
#                    'adj_volume': 25362636.0,
#                    'close': 208.49,
#                    'date': datetime.date(2018, 11, 8),
#                    'frequency': 'daily',
#                    'high': 210.12,
#                    'intraperiod': False,
#                    'low': 206.75,
#                    'open': 209.98,
#                    'volume': 25362636.0},
#                   {'adj_close': 207.527345023168,
#                    'adj_high': 207.636075711201,
#                    'adj_low': 201.774503165417,
#                    'adj_open': 203.59327103797,
#                    'adj_volume': 33424434.0,
#                    'close': 209.95,
#                    'date': datetime.date(2018, 11, 7),
#                    'frequency': 'daily',
#                    'high': 210.06,
#                    'intraperiod': False,
#                    'low': 204.13,
#                    'open': 205.97,
#                    'volume': 33424434.0},
#                   {'adj_close': 201.418657277308,
#                    'adj_high': 202.357695037594,
#                    'adj_low': 199.362658812682,
#                    'adj_open': 199.590004796752,
#                    'adj_volume': 31882881.0,
#                    'close': 203.77,
#                    'date': datetime.date(2018, 11, 6),
#                    'frequency': 'daily',
#                    'high': 204.72,
#                    'intraperiod': False,
#                    'low': 201.69,
#                    'open': 201.92,
#                    'volume': 31882881.0},
#                   {'adj_close': 199.263812732652,
#                    'adj_high': 202.031502973495,
#                    'adj_low': 195.883276795623,
#                    'adj_open': 201.942541501468,
#                    'adj_volume': 66163669.0,
#                    'close': 201.59,
#                    'date': datetime.date(2018, 11, 5),
#                    'frequency': 'daily',
#                    'high': 204.39,
#                    'intraperiod': False,
#                    'low': 198.17,
#                    'open': 204.3,
#                    'volume': 66163669.0},
#                   {'adj_close': 205.085846846425,
#                    'adj_high': 211.184649984281,
#                    'adj_low': 203.059502205808,
#                    'adj_open': 207.131960703047,
#                    'adj_volume': 91328654.0,
#                    'close': 207.48,
#                    'date': datetime.date(2018, 11, 2),
#                    'frequency': 'daily',
#                    'high': 213.65,
#                    'intraperiod': False,
#                    'low': 205.43,
#                    'open': 209.55,
#                    'volume': 91328654.0},
#                   {'adj_close': 219.655759042859,
#                    'adj_high': 219.794143554901,
#                    'adj_low': 214.308186113232,
#                    'adj_open': 216.522338305906,
#                    'adj_volume': 58323180.0,
#                    'close': 222.22,
#                    'date': datetime.date(2018, 11, 1),
#                    'frequency': 'daily',
#                    'high': 222.36,
#                    'intraperiod': False,
#                    'low': 216.81,
#                    'open': 219.05,
#                    'volume': 58323180.0},
#                   {'adj_close': 216.334530753848,
#                    'adj_high': 217.906183426327,
#                    'adj_low': 214.120378561174,
#                    'adj_open': 214.377378369253,
#                    'adj_volume': 38358933.0,
#                    'close': 218.86,
#                    'date': datetime.date(2018, 10, 31),
#                    'frequency': 'daily',
#                    'high': 220.45,
#                    'intraperiod': False,
#                    'low': 216.62,
#                    'open': 216.88,
#                    'volume': 38358933.0},
#                   {'adj_close': 210.838688704176,
#                    'adj_high': 212.696995008741,
#                    'adj_low': 206.855191678963,
#                    'adj_open': 208.713497983529,
#                    'adj_volume': 36659990.0,
#                    'close': 213.3,
#                    'date': datetime.date(2018, 10, 30),
#                    'frequency': 'daily',
#                    'high': 215.18,
#                    'intraperiod': False,
#                    'low': 209.27,
#                    'open': 211.15,
#                    'volume': 36659990.0},
#                   {'adj_close': 209.790920255857,
#                    'adj_high': 217.154953218098,
#                    'adj_low': 203.711886334006,
#                    'adj_open': 216.660722817948,
#                    'adj_volume': 45935520.0,
#                    'close': 212.24,
#                    'date': datetime.date(2018, 10, 29),
#                    'frequency': 'daily',
#                    'high': 219.69,
#                    'intraperiod': False,
#                    'low': 206.09,
#                    'open': 219.19,
#                    'volume': 45935520.0},
#                   {'adj_close': 213.804071105078,
#                    'adj_high': 217.649183618249,
#                    'adj_low': 210.215958399986,
#                    'adj_open': 213.408686784958,
#                    'adj_volume': 47258375.0,
#                    'close': 216.3,
#                    'date': datetime.date(2018, 10, 26),
#                    'frequency': 'daily',
#                    'high': 220.19,
#                    'intraperiod': False,
#                    'low': 212.67,
#                    'open': 215.9,
#                    'volume': 47258375.0},
#                   {'adj_close': 217.263683906131,
#                    'adj_high': 218.825451970607,
#                    'adj_low': 214.248878465214,
#                    'adj_open': 215.197800833502,
#                    'adj_volume': 29855768.0,
#                    'close': 219.8,
#                    'date': datetime.date(2018, 10, 25),
#                    'frequency': 'daily',
#                    'high': 221.38,
#                    'intraperiod': False,
#                    'low': 216.75,
#                    'open': 217.71,
#                    'volume': 29855768.0},
#                   {'adj_close': 212.608033536714,
#                    'adj_high': 221.642565251464,
#                    'adj_low': 212.064380096549,
#                    'adj_open': 220.031374146974,
#                    'adj_volume': 40925163.0,
#                    'close': 215.09,
#                    'date': datetime.date(2018, 10, 24),
#                    'frequency': 'daily',
#                    'high': 224.23,
#                    'intraperiod': False,
#                    'low': 214.54,
#                    'open': 222.6,
#                    'volume': 40925163.0},
#                   {'adj_close': 220.159874051013,
#                    'adj_high': 220.673873667169,
#                    'adj_low': 212.222533824597,
#                    'adj_open': 213.339494528937,
#                    'adj_volume': 38767846.0,
#                    'close': 222.73,
#                    'date': datetime.date(2018, 10, 23),
#                    'frequency': 'daily',
#                    'high': 223.25,
#                    'intraperiod': False,
#                    'low': 214.7,
#                    'open': 215.83,
#                    'volume': 38767846.0},
#                   {'adj_close': 218.103875586387,
#                    'adj_high': 220.782604355202,
#                    'adj_low': 216.413607617872,
#                    'adj_open': 217.253799298128,
#                    'adj_volume': 28792082.0,
#                    'close': 220.65,
#                    'date': datetime.date(2018, 10, 22),
#                    'frequency': 'daily',
#                    'high': 223.36,
#                    'intraperiod': False,
#                    'low': 218.94,
#                    'open': 219.79,
#                    'volume': 28792082.0},
#                   {'adj_close': 216.779338113984,
#                    'adj_high': 218.70683667457,
#                    'adj_low': 214.921031809418,
#                    'adj_open': 215.543762113608,
#                    'adj_volume': 33078726.0,
#                    'close': 219.31,
#                    'date': datetime.date(2018, 10, 19),
#                    'frequency': 'daily',
#                    'high': 221.26,
#                    'intraperiod': False,
#                    'low': 217.43,
#                    'open': 218.06,
#                    'volume': 33078726.0},
#                   {'adj_close': 213.527302080994,
#                    'adj_high': 217.204376258113,
#                    'adj_low': 210.542150464085,
#                    'adj_open': 215.346069953548,
#                    'adj_volume': 32581315.0,
#                    'close': 216.02,
#                    'date': datetime.date(2018, 10, 18),
#                    'frequency': 'daily',
#                    'high': 219.74,
#                    'intraperiod': False,
#                    'low': 213.0,
#                    'open': 217.86,
#                    'volume': 32581315.0},
#                   {'adj_close': 218.637644418549,
#                    'adj_high': 220.070912578986,
#                    'adj_low': 216.808991937993,
#                    'adj_open': 219.734835906883,
#                    'adj_volume': 22885397.0,
#                    'close': 221.19,
#                    'date': datetime.date(2018, 10, 17),
#                    'frequency': 'daily',
#                    'high': 222.64,
#                    'intraperiod': False,
#                    'low': 219.34,
#                    'open': 222.3,
#                    'volume': 22885397.0},
#                   {'adj_close': 219.586566786838,
#                    'adj_high': 220.416873859091,
#                    'adj_low': 214.261431917377,
#                    'adj_open': 216.403723009869,
#                    'adj_volume': 29183963.0,
#                    'close': 222.15,
#                    'date': datetime.date(2018, 10, 16),
#                    'frequency': 'daily',
#                    'high': 222.99,
#                    'intraperiod': False,
#                    'low': 216.7627,
#                    'open': 218.93,
#                    'volume': 29183963.0},
#                   {'adj_close': 214.851839553397,
#                    'adj_high': 219.270259330742,
#                    'adj_low': 214.76287808137,
#                    'adj_open': 218.60799059454,
#                    'adj_volume': 30791007.0,
#                    'close': 217.36,
#                    'date': datetime.date(2018, 10, 15),
#                    'frequency': 'daily',
#                    'high': 221.83,
#                    'intraperiod': False,
#                    'low': 217.27,
#                    'open': 221.16,
#                    'volume': 30791007.0},
#                   {'adj_close': 219.547028354826,
#                    'adj_high': 220.308143171058,
#                    'adj_low': 214.337839937241,
#                    'adj_open': 217.876529602318,
#                    'adj_volume': 40337851.0,
#                    'close': 222.11,
#                    'date': datetime.date(2018, 10, 12),
#                    'frequency': 'daily',
#                    'high': 222.88,
#                    'intraperiod': False,
#                    'low': 216.84,
#                    'open': 220.42,
#                    'volume': 40337851.0},
#                   {'adj_close': 211.975418624522,
#                    'adj_high': 216.967145666041,
#                    'adj_low': 209.869997119881,
#                    'adj_open': 212.044610880543,
#                    'adj_volume': 53124392.0,
#                    'close': 214.45,
#                    'date': datetime.date(2018, 10, 11),
#                    'frequency': 'daily',
#                    'high': 219.5,
#                    'intraperiod': False,
#                    'low': 212.32,
#                    'open': 214.52,
#                    'volume': 53124392.0},
#                   {'adj_close': 213.863378753096,
#                    'adj_high': 223.738102148102,
#                    'adj_low': 213.556955905003,
#                    'adj_open': 222.858372035834,
#                    'adj_volume': 41990554.0,
#                    'close': 216.36,
#                    'date': datetime.date(2018, 10, 10),
#                    'frequency': 'daily',
#                    'high': 226.35,
#                    'intraperiod': False,
#                    'low': 216.05,
#                    'open': 225.46,
#                    'volume': 41990554.0},
#                   {'adj_close': 224.252101764258,
#                    'adj_high': 224.647486084379,
#                    'adj_low': 219.681656715827,
#                    'adj_open': 221.059373379287,
#                    'adj_volume': 26891029.0,
#                    'close': 226.87,
#                    'date': datetime.date(2018, 10, 9),
#                    'frequency': 'daily',
#                    'high': 227.27,
#                    'intraperiod': False,
#                    'low': 222.2462,
#                    'open': 223.64,
#                    'volume': 26891029.0},
#                   {'adj_close': 221.187873283326,
#                    'adj_high': 222.205987907636,
#                    'adj_low': 217.659068226252,
#                    'adj_open': 219.645874434856,
#                    'adj_volume': 29663923.0,
#                    'close': 223.77,
#                    'date': datetime.date(2018, 10, 8),
#                    'frequency': 'daily',
#                    'high': 224.8,
#                    'intraperiod': False,
#                    'low': 220.2,
#                    'open': 222.21,
#                    'volume': 29663923.0},
#                   {'adj_close': 221.701872899482,
#                    'adj_high': 225.774331396722,
#                    'adj_low': 218.034683330366,
#                    'adj_open': 225.329524036586,
#                    'adj_volume': 33580463.0,
#                    'close': 224.29,
#                    'date': datetime.date(2018, 10, 5),
#                    'frequency': 'daily',
#                    'high': 228.41,
#                    'intraperiod': False,
#                    'low': 220.58,
#                    'open': 227.96,
#                    'volume': 33580463.0},
#                   {'adj_close': 225.359177860595,
#                    'adj_high': 229.668866949907,
#                    'adj_low': 224.113717252216,
#                    'adj_open': 228.116983493435,
#                    'adj_volume': 32042000.0,
#                    'close': 227.99,
#                    'date': datetime.date(2018, 10, 4),
#                    'frequency': 'daily',
#                    'high': 232.35,
#                    'intraperiod': False,
#                    'low': 226.73,
#                    'open': 230.78,
#                    'volume': 32042000.0},
#                   {'adj_close': 229.392097925823,
#                    'adj_high': 230.775943046244,
#                    'adj_low': 227.128522693134,
#                    'adj_open': 227.395407109215,
#                    'adj_volume': 28654799.0,
#                    'close': 232.07,
#                    'date': datetime.date(2018, 10, 3),
#                    'frequency': 'daily',
#                    'high': 233.47,
#                    'intraperiod': False,
#                    'low': 229.78,
#                    'open': 230.05,
#                    'volume': 28654799.0},
#                   {'adj_close': 226.634292292983,
#                    'adj_high': 227.3459840692,
#                    'adj_low': 224.014871172186,
#                    'adj_open': 224.627716868373,
#                    'adj_volume': 24788170.0,
#                    'close': 229.28,
#                    'date': datetime.date(2018, 10, 2),
#                    'frequency': 'daily',
#                    'high': 230.0,
#                    'intraperiod': False,
#                    'low': 226.63,
#                    'open': 227.25,
#                    'volume': 24788170.0},
#                   {'adj_close': 224.637601476376,
#                    'adj_high': 226.772676805026,
#                    'adj_low': 223.738102148102,
#                    'adj_open': 225.319639428583,
#                    'adj_volume': 23600802.0,
#                    'close': 227.26,
#                    'date': datetime.date(2018, 10, 1),
#                    'frequency': 'daily',
#                    'high': 229.42,
#                    'intraperiod': False,
#                    'low': 226.35,
#                    'open': 227.95,
#                    'volume': 23600802.0},
#                   {'adj_close': 223.135141059918,
#                    'adj_high': 223.233987139948,
#                    'adj_low': 221.434988483401,
#                    'adj_open': 222.196103299633,
#                    'adj_volume': 22929364.0,
#                    'close': 225.74,
#                    'date': datetime.date(2018, 9, 28),
#                    'frequency': 'daily',
#                    'high': 225.84,
#                    'intraperiod': False,
#                    'low': 224.02,
#                    'open': 224.79,
#                    'volume': 22929364.0},
#                   {'adj_close': 222.354257027681,
#                    'adj_high': 223.827063620129,
#                    'adj_low': 220.960527299256,
#                    'adj_open': 221.237296323341,
#                    'adj_volume': 30181227.0,
#                    'close': 224.95,
#                    'date': datetime.date(2018, 9, 27),
#                    'frequency': 'daily',
#                    'high': 226.44,
#                    'intraperiod': False,
#                    'low': 223.54,
#                    'open': 223.82,
#                    'volume': 30181227.0},
#                   {'adj_close': 217.876529602318,
#                    'adj_high': 221.16810406732,
#                    'adj_low': 217.224145474119,
#                    'adj_open': 218.449836866492,
#                    'adj_volume': 23984706.0,
#                    'close': 220.42,
#                    'date': datetime.date(2018, 9, 26),
#                    'frequency': 'daily',
#                    'high': 223.75,
#                    'intraperiod': False,
#                    'low': 219.76,
#                    'open': 221.0,
#                    'volume': 23984706.0},
#                   {'adj_close': 219.62610521885,
#                    'adj_high': 220.24883552304,
#                    'adj_low': 217.164837826101,
#                    'adj_open': 217.214260866116,
#                    'adj_volume': 24554379.0,
#                    'close': 222.19,
#                    'date': datetime.date(2018, 9, 25),
#                    'frequency': 'daily',
#                    'high': 222.82,
#                    'intraperiod': False,
#                    'low': 219.7,
#                    'open': 219.75,
#                    'volume': 24554379.0},
#                   {'adj_close': 218.242260098429,
#                    'adj_high': 218.70683667457,
#                    'adj_low': 214.130263169177,
#                    'adj_open': 214.318070721235,
#                    'adj_volume': 27693358.0,
#                    'close': 220.79,
#                    'date': datetime.date(2018, 9, 24),
#                    'frequency': 'daily',
#                    'high': 221.26,
#                    'intraperiod': False,
#                    'low': 216.63,
#                    'open': 216.82,
#                    'volume': 27693358.0},
#                   {'adj_close': 215.148377793487,
#                    'adj_high': 218.805682754601,
#                    'adj_low': 214.782647297376,
#                    'adj_open': 218.232375490426,
#                    'adj_volume': 96246748.0,
#                    'close': 217.66,
#                    'date': datetime.date(2018, 9, 21),
#                    'frequency': 'daily',
#                    'high': 221.36,
#                    'intraperiod': False,
#                    'low': 217.29,
#                    'open': 220.78,
#                    'volume': 96246748.0},
#                   {'adj_close': 217.4910298902,
#                    'adj_high': 219.715066690877,
#                    'adj_low': 216.621184385936,
#                    'adj_open': 217.698606658264,
#                    'adj_volume': 26608794.0,
#                    'close': 220.03,
#                    'date': datetime.date(2018, 9, 20),
#                    'frequency': 'daily',
#                    'high': 222.28,
#                    'intraperiod': False,
#                    'low': 219.15,
#                    'open': 220.24,
#                    'volume': 26608794.0},
#                   {'adj_close': 215.850184961701,
#                    'adj_high': 217.085760962077,
#                    'adj_low': 212.815610304777,
#                    'adj_open': 215.97868486574,
#                    'adj_volume': 27123833.0,
#                    'close': 218.37,
#                    'date': datetime.date(2018, 9, 19),
#                    'frequency': 'daily',
#                    'high': 219.62,
#                    'intraperiod': False,
#                    'low': 215.3,
#                    'open': 218.5,
#                    'volume': 27123833.0},
#                   {'adj_close': 215.721685057662,
#                    'adj_high': 219.290028546748,
#                    'adj_low': 214.614608961325,
#                    'adj_open': 215.276877697526,
#                    'adj_volume': 31571712.0,
#                    'close': 218.24,
#                    'date': datetime.date(2018, 9, 18),
#                    'frequency': 'daily',
#                    'high': 221.85,
#                    'intraperiod': False,
#                    'low': 217.12,
#                    'open': 217.79,
#                    'volume': 31571712.0},
#                   {'adj_close': 215.365839169554,
#                    'adj_high': 220.377335427079,
#                    'adj_low': 214.76287808137,
#                    'adj_open': 219.586566786838,
#                    'adj_volume': 37195133.0,
#                    'close': 217.88,
#                    'date': datetime.date(2018, 9, 17),
#                    'frequency': 'daily',
#                    'high': 222.95,
#                    'intraperiod': False,
#                    'low': 217.27,
#                    'open': 222.15,
#                    'volume': 37195133.0},
#                   {'adj_close': 221.257065539347,
#                    'adj_high': 224.222447940249,
#                    'adj_low': 219.95427420455,
#                    'adj_open': 223.145025667921,
#                    'adj_volume': 31999289.0,
#                    'close': 223.84,
#                    'date': datetime.date(2018, 9, 14),
#                    'frequency': 'daily',
#                    'high': 226.84,
#                    'intraperiod': False,
#                    'low': 222.522,
#                    'open': 225.75,
#                    'volume': 31999289.0},
#                   {'adj_close': 223.79740979612,
#                    'adj_high': 225.715023748704,
#                    'adj_low': 220.001720322965,
#                    'adj_open': 220.94075808325,
#                    'adj_volume': 41706377.0,
#                    'close': 226.41,
#                    'date': datetime.date(2018, 9, 13),
#                    'frequency': 'daily',
#                    'high': 228.35,
#                    'intraperiod': False,
#                    'low': 222.57,
#                    'open': 223.52,
#                    'volume': 41706377.0},
#                   {'adj_close': 218.519029122513,
#                    'adj_high': 222.403680067696,
#                    'adj_low': 217.303222338143,
#                    'adj_open': 222.344372419678,
#                    'adj_volume': 49278740.0,
#                    'close': 221.07,
#                    'date': datetime.date(2018, 9, 12),
#                    'frequency': 'daily',
#                    'high': 225.0,
#                    'intraperiod': False,
#                    'low': 219.84,
#                    'open': 224.94,
#                    'volume': 49278740.0},
#                   {'adj_close': 221.26695014735,
#                    'adj_high': 221.710769046685,
#                    'adj_low': 214.061070913156,
#                    'adj_open': 215.494339073593,
#                    'adj_volume': 35749049.0,
#                    'close': 223.85,
#                    'date': datetime.date(2018, 9, 11),
#                    'frequency': 'daily',
#                    'high': 224.299,
#                    'intraperiod': False,
#                    'low': 216.56,
#                    'open': 218.01,
#                    'volume': 35749049.0},
#                   {'adj_close': 215.810646529689,
#                    'adj_high': 219.290028546748,
#                    'adj_low': 213.972109441129,
#                    'adj_open': 218.400413826477,
#                    'adj_volume': 39516453.0,
#                    'close': 218.33,
#                    'date': datetime.date(2018, 9, 10),
#                    'frequency': 'daily',
#                    'high': 221.85,
#                    'intraperiod': False,
#                    'low': 216.47,
#                    'open': 220.95,
#                    'volume': 39516453.0},
#                   {'adj_close': 218.746375106583,
#                    'adj_high': 222.769410563807,
#                    'adj_low': 218.163183234405,
#                    'adj_open': 219.290028546748,
#                    'adj_volume': 37619810.0,
#                    'close': 221.3,
#                    'date': datetime.date(2018, 9, 7),
#                    'frequency': 'daily',
#                    'high': 225.37,
#                    'intraperiod': False,
#                    'low': 220.71,
#                    'open': 221.85,
#                    'volume': 37619810.0},
#                   {'adj_close': 220.525604547124,
#                    'adj_high': 224.726562948403,
#                    'adj_low': 218.746375106583,
#                    'adj_open': 223.619486852066,
#                    'adj_volume': 34289976.0,
#                    'close': 223.1,
#                    'date': datetime.date(2018, 9, 6),
#                    'frequency': 'daily',
#                    'high': 227.35,
#                    'intraperiod': False,
#                    'low': 221.3,
#                    'open': 226.23,
#                    'volume': 34289976.0},
#                   {'adj_close': 224.252101764258,
#                    'adj_high': 227.019792005101,
#                    'adj_low': 222.502526147726,
#                    'adj_open': 226.347638660896,
#                    'adj_volume': 33332960.0,
#                    'close': 226.87,
#                    'date': datetime.date(2018, 9, 5),
#                    'frequency': 'daily',
#                    'high': 229.67,
#                    'intraperiod': False,
#                    'low': 225.1,
#                    'open': 228.99,
#                    'volume': 33332960.0},
#                   {'adj_close': 225.724908356707,
#                    'adj_high': 226.535446212953,
#                    'adj_low': 224.014871172186,
#                    'adj_open': 225.774331396722,
#                    'adj_volume': 27390132.0,
#                    'close': 228.36,
#                    'date': datetime.date(2018, 9, 4),
#                    'frequency': 'daily',
#                    'high': 229.18,
#                    'intraperiod': False,
#                    'low': 226.63,
#                    'open': 228.41,
#                    'volume': 27390132.0},
#                   {'adj_close': 225.003331972487,
#                    'adj_high': 226.22902336486,
#                    'adj_low': 223.392140867997,
#                    'adj_open': 223.89625587615,
#                    'adj_volume': 43340134.0,
#                    'close': 227.63,
#                    'date': datetime.date(2018, 8, 31),
#                    'frequency': 'daily',
#                    'high': 228.87,
#                    'intraperiod': False,
#                    'low': 226.0,
#                    'open': 226.51,
#                    'volume': 43340134.0},
#                   {'adj_close': 222.433333891705,
#                    'adj_high': 225.626062276677,
#                    'adj_low': 219.833681986913,
#                    'adj_open': 220.673873667169,
#                    'adj_volume': 48793824.0,
#                    'close': 225.03,
#                    'date': datetime.date(2018, 8, 30),
#                    'frequency': 'daily',
#                    'high': 228.26,
#                    'intraperiod': False,
#                    'low': 222.4,
#                    'open': 223.25,
#                    'volume': 48793824.0},
#                   {'adj_close': 220.406989251088,
#                    'adj_high': 220.911104259241,
#                    'adj_low': 216.878184194014,
#                    'adj_open': 217.609645186237,
#                    'adj_volume': 27254804.0,
#                    'close': 222.98,
#                    'date': datetime.date(2018, 8, 29),
#                    'frequency': 'daily',
#                    'high': 223.49,
#                    'intraperiod': False,
#                    'low': 219.41,
#                    'open': 220.15,
#                    'volume': 27254804.0},
#                   {'adj_close': 217.164837826101,
#                    'adj_high': 217.995144898354,
#                    'adj_low': 216.393838401866,
#                    'adj_open': 216.482799873894,
#                    'adj_volume': 22776766.0,
#                    'close': 219.7,
#                    'date': datetime.date(2018, 8, 28),
#                    'frequency': 'daily',
#                    'high': 220.54,
#                    'intraperiod': False,
#                    'low': 218.92,
#                    'open': 219.01,
#                    'volume': 22776766.0},
#                   {'adj_close': 215.425146817572,
#                    'adj_high': 216.215915457812,
#                    'adj_low': 213.833724929087,
#                    'adj_open': 214.644262785334,
#                    'adj_volume': 20525117.0,
#                    'close': 217.94,
#                    'date': datetime.date(2018, 8, 27),
#                    'frequency': 'daily',
#                    'high': 218.74,
#                    'intraperiod': False,
#                    'low': 216.33,
#                    'open': 217.15,
#                    'volume': 20525117.0},
#                   {'adj_close': 213.665686593036,
#                    'adj_high': 214.397147585259,
#                    'adj_low': 212.62780275272,
#                    'adj_open': 214.100609345168,
#                    'adj_volume': 18476356.0,
#                    'close': 216.16,
#                    'date': datetime.date(2018, 8, 24),
#                    'frequency': 'daily',
#                    'high': 216.9,
#                    'intraperiod': False,
#                    'low': 215.11,
#                    'open': 216.6,
#                    'volume': 18476356.0},
#                   {'adj_close': 213.003417856834,
#                    'adj_high': 214.545416705304,
#                    'adj_low': 212.123687744567,
#                    'adj_open': 212.173110784582,
#                    'adj_volume': 18883224.0,
#                    'close': 215.49,
#                    'date': datetime.date(2018, 8, 23),
#                    'frequency': 'daily',
#                    'high': 217.05,
#                    'intraperiod': False,
#                    'low': 214.6,
#                    'open': 214.65,
#                    'volume': 18883224.0},
#                   {'adj_close': 212.568495104702,
#                    'adj_high': 213.863378753096,
#                    'adj_low': 211.372457536338,
#                    'adj_open': 211.629457344416,
#                    'adj_volume': 19018131.0,
#                    'close': 215.05,
#                    'date': datetime.date(2018, 8, 22),
#                    'frequency': 'daily',
#                    'high': 216.36,
#                    'intraperiod': False,
#                    'low': 213.84,
#                    'open': 214.1,
#                    'volume': 19018131.0},
#                   {'adj_close': 212.558610496699,
#                    'adj_high': 214.683801217346,
#                    'adj_low': 211.555322784394,
#                    'adj_open': 214.298301505229,
#                    'adj_volume': 26159755.0,
#                    'close': 215.04,
#                    'date': datetime.date(2018, 8, 21),
#                    'frequency': 'daily',
#                    'high': 217.19,
#                    'intraperiod': False,
#                    'low': 214.025,
#                    'open': 216.8,
#                    'volume': 26159755.0},
#                   {'adj_close': 212.973764032825,
#                    'adj_high': 216.650838209945,
#                    'adj_low': 212.62780275272,
#                    'adj_open': 215.58330054562,
#                    'adj_volume': 30287695.0,
#                    'close': 215.46,
#                    'date': datetime.date(2018, 8, 20),
#                    'frequency': 'daily',
#                    'high': 219.18,
#                    'intraperiod': False,
#                    'low': 215.11,
#                    'open': 218.1,
#                    'volume': 30287695.0},
#                   {'adj_close': 215.069300929463,
#                    'adj_high': 215.435031425575,
#                    'adj_low': 210.700304192133,
#                    'adj_open': 210.977073216218,
#                    'adj_volume': 35426997.0,
#                    'close': 217.58,
#                    'date': datetime.date(2018, 8, 17),
#                    'frequency': 'daily',
#                    'high': 217.95,
#                    'intraperiod': False,
#                    'low': 213.16,
#                    'open': 213.44,
#                    'volume': 35426997.0},
#                   {'adj_close': 210.858457920182,
#                    'adj_high': 211.34487948001,
#                    'adj_low': 209.029805439625,
#                    'adj_open': 209.306574463709,
#                    'adj_volume': 28500367.0,
#                    'close': 213.32,
#                    'date': datetime.date(2018, 8, 16),
#                    'frequency': 'daily',
#                    'high': 213.8121,
#                    'intraperiod': False,
#                    'low': 211.47,
#                    'open': 211.75,
#                    'volume': 28500367.0},
#                   {'adj_close': 207.813998655255,
#                    'adj_high': 208.308229055405,
#                    'adj_low': 205.92603852668,
#                    'adj_open': 206.805768638948,
#                    'adj_volume': 28807564.0,
#                    'close': 210.24,
#                    'date': datetime.date(2018, 8, 15),
#                    'frequency': 'daily',
#                    'high': 210.74,
#                    'intraperiod': False,
#                    'low': 208.33,
#                    'open': 209.22,
#                    'volume': 28807564.0},
#                   {'adj_close': 207.329652863107,
#                    'adj_high': 208.130306111351,
#                    'adj_low': 205.856846270659,
#                    'adj_open': 207.729979487229,
#                    'adj_volume': 20748010.0,
#                    'close': 209.75,
#                    'date': datetime.date(2018, 8, 14),
#                    'frequency': 'daily',
#                    'high': 210.56,
#                    'intraperiod': False,
#                    'low': 208.26,
#                    'open': 210.155,
#                    'volume': 20748010.0},
#                   {'adj_close': 206.459807358843,
#                    'adj_high': 208.517782745069,
#                    'adj_low': 205.303308222491,
#                    'adj_open': 205.303308222491,
#                    'adj_volume': 25890880.0,
#                    'close': 208.87,
#                    'date': datetime.date(2018, 8, 13),
#                    'frequency': 'daily',
#                    'high': 210.952,
#                    'intraperiod': False,
#                    'low': 207.7,
#                    'open': 207.7,
#                    'volume': 25890880.0},
#                   {'adj_close': 205.13526988644,
#                    'adj_high': 206.687153342912,
#                    'adj_low': 204.285193598181,
#                    'adj_open': 204.967231550388,
#                    'adj_volume': 24611202.0,
#                    'close': 207.53,
#                    'date': datetime.date(2018, 8, 10),
#                    'frequency': 'daily',
#                    'high': 209.1,
#                    'intraperiod': False,
#                    'low': 206.67,
#                    'open': 207.36,
#                    'volume': 24611202.0},
#                   {'adj_close': 205.748115582626,
#                    'adj_high': 206.634621251069,
#                    'adj_low': 204.093305001533,
#                    'adj_open': 204.172105505394,
#                    'adj_volume': 23492626.0,
#                    'close': 208.88,
#                    'date': datetime.date(2018, 8, 9),
#                    'frequency': 'daily',
#                    'high': 209.78,
#                    'intraperiod': False,
#                    'low': 207.2,
#                    'open': 207.28,
#                    'volume': 23492626.0},
#                   {'adj_close': 204.142555316446,
#                    'adj_high': 204.694158843477,
#                    'adj_low': 201.453488122169,
#                    'adj_open': 202.960547758522,
#                    'adj_volume': 22525487.0,
#                    'close': 207.25,
#                    'date': datetime.date(2018, 8, 8),
#                    'frequency': 'daily',
#                    'high': 207.81,
#                    'intraperiod': False,
#                    'low': 204.52,
#                    'open': 206.05,
#                    'volume': 22525487.0}]}

# %%
company_api = intrinio_sdk.CompanyApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
next_page = '' # str | Gets the next page of data from a previous API call (optional)

try:
  api_response = company_api.get_company_securities(identifier, next_page=next_page)
  pprint(api_response)
except ApiException as e:
  print("Exception when calling CompanyApi->get_company_securities: %s\r\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'next_page': None,
#  'securities': [{'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000B9XRY4',
#                  'composite_ticker': 'AAPL:US',
#                  'currency': 'USD',
#                  'figi': 'BBG000B9Y5X2',
#                  'id': 'sec_agjrgj',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000KWV421',
#                  'composite_ticker': 'AAPL:MM',
#                  'currency': 'MXN',
#                  'figi': 'BBG000KWV4C0',
#                  'id': 'sec_zEVDQy',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000LF8110',
#                  'composite_ticker': 'AAPL:SW',
#                  'currency': 'CHF',
#                  'figi': 'BBG002JV1HL4',
#                  'id': 'sec_gQOrlz',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0KP5',
#                  'id': 'sec_gPK6Ly',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG00GQ6RZG8',
#                  'composite_ticker': 'AAPL:AV',
#                  'currency': 'EUR',
#                  'figi': 'BBG00GQ6RZH7',
#                  'id': 'sec_g4QkQZ',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0MF2',
#                  'id': 'sec_zvxM2w',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DGZJ27',
#                  'id': 'sec_gDk3m4',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0MN3',
#                  'id': 'sec_ge8K59',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0L82',
#                  'id': 'sec_z8BZ7d',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG0032FLQC3',
#                  'composite_ticker': 'AAPL:CI',
#                  'currency': 'USD',
#                  'figi': 'BBG0032FLQD2',
#                  'id': 'sec_XOe7ZV',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG009S1W8C1',
#                  'composite_ticker': 'AAPL:PE',
#                  'currency': 'USD',
#                  'figi': 'BBG009S1W8D0',
#                  'id': 'sec_zr093L',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0NM2',
#                  'id': 'sec_zqaKrx',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0P83',
#                  'id': 'sec_zqaqe5',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000DGZJ27',
#                  'composite_ticker': 'APC:GR',
#                  'currency': 'EUR',
#                  'figi': 'BBG000DH0LW5',
#                  'id': 'sec_g2DQGo',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'APC'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG00J7BK3N2',
#                  'composite_ticker': 'AAPL:IM',
#                  'currency': 'EUR',
#                  'figi': 'BBG00J7BK3P0',
#                  'id': 'sec_gwNen2',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG000LF8110',
#                  'composite_ticker': 'AAPL:SW',
#                  'currency': 'USD',
#                  'figi': 'BBG002JV1HL4',
#                  'id': 'sec_y3dGJM',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG009CHNPJ8',
#                  'composite_ticker': 'AAPL:SW',
#                  'currency': 'EUR',
#                  'figi': 'BBG009CHNPL5',
#                  'id': 'sec_yRWDZx',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG0032FLQC3',
#                  'composite_ticker': 'AAPL:CI',
#                  'currency': 'CLP',
#                  'figi': 'BBG0032FLQD2',
#                  'id': 'sec_gNVdAN',
#                  'name': 'Apple Inc',
#                  'share_class_figi': None,
#                  'ticker': 'AAPL'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG00JPR0LW9',
#                  'composite_ticker': '0R2V:LN',
#                  'currency': 'USD',
#                  'figi': 'BBG00JPR0LX8',
#                  'id': 'sec_zE8ERn',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': '0R2V'},
#                 {'code': 'EQS',
#                  'company_id': 'com_NX6GzO',
#                  'composite_figi': 'BBG001BHSV71',
#                  'composite_ticker': 'AAPL:CB',
#                  'currency': 'COP',
#                  'figi': 'BBG001BHSV80',
#                  'id': 'sec_gxVLG5',
#                  'name': 'Apple Inc',
#                  'share_class_figi': 'BBG001S5N8V8',
#                  'ticker': 'AAPL'}]}

# %%
fundamentals_api = intrinio_sdk.FundamentalsApi()

identifier = 'AAPL' # str | A Company identifier (Ticker, CIK, LEI, Intrinio ID)
statement_code = 'income_statement' # str | The statement code
fiscal_year = 2017 # int | The fiscal year
fiscal_period = 'FY' # str | The fiscal period

try:
  api_response = fundamentals_api.lookup_fundamental(identifier, statement_code, fiscal_year, fiscal_period)
  pprint(api_response)
except ApiException as e:
  print("Exception when calling FundamentalsApi->lookup_fundamental: %s\r\n" % e)
# Out:
# {'company': {'cik': '0000320193',
#              'id': 'com_NX6GzO',
#              'lei': 'HWUPKR0MPOU8FGXBT394',
#              'name': 'Apple Inc',
#              'ticker': 'AAPL'},
#  'end_date': datetime.date(2017, 9, 30),
#  'filing_date': datetime.datetime(2018, 11, 5, 8, 1, 40, tzinfo=tzutc()),
#  'fiscal_period': 'FY',
#  'fiscal_year': 2017.0,
#  'id': 'fun_XavkYm',
#  'start_date': datetime.date(2016, 9, 25),
#  'statement_code': 'income_statement',
#  'type': 'restated'}
