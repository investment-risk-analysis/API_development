# %%
# !pip install quandl
# Out:
# ...
#      |████████████████████████████████| 61kB 3.8MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 81kB 4.6MB/s eta 0:00:011
# ...
#   Stored in directory: /Users/azel/Library/Caches/pip/wheels/9f/5a/d3/6fc3bf6516d2a3eb7e18f9f28b472110b59325f3f258fe9211
# Successfully built inflection
# ...
#   Found existing installation: more-itertools 7.0.0
#     Uninstalling more-itertools-7.0.0:
#       Successfully uninstalled more-itertools-7.0.0
# ...

# %%
from decouple import config
import quandl

df = quandl.get("USTREASURY/BILLRATES", authtoken=config('QUANDL_KEY'))
df.head()
# Out:
#             4 Wk Bank Discount Rate  4 Wk Coupon Equiv  \
# Date
# 2002-01-02                     1.71               1.74
# 2002-01-03                     1.70               1.73
# 2002-01-04                     1.69               1.72
# 2002-01-07                     1.68               1.71
# 2002-01-08                     1.67               1.69
#
#             8 Wk Bank Discount Rate  8 Wk Coupon Equiv  \
# Date
# 2002-01-02                      NaN                NaN
# 2002-01-03                      NaN                NaN
# 2002-01-04                      NaN                NaN
# 2002-01-07                      NaN                NaN
# 2002-01-08                      NaN                NaN
#
#             13 Wk Bank Discount Rate  13 Wk Coupon Equiv  \
# Date
# 2002-01-02                      1.71                1.74
# 2002-01-03                      1.70                1.73
# 2002-01-04                      1.69                1.72
# ...
